# %%
import sys
print(sys.executable)
# Out:
# c:\Users\snels\AppData\Local\Programs\Python\Python314\python.exe

# %% [markdown]
# This folder is used to test code

# %%
# import libraries 
import pandas as pd
from ipyleaflet import Map, Marker, Circle, basemaps, LayersControl
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 # import libraries
#       2 import pandas as pd
# ----> 3 from ipyleaflet import Map, Marker, Circle, basemaps, LayersControl
#       4 import os
#
# ModuleNotFoundError: No module named 'ipyleaflet'

# %%
# manually set map coordinates 

address = "2632 Central Avenue, St. Petersburg, FL"

latitude = 27.7715
longitude = -82.6687
